# %% [markdown]
# <a href="https://colab.research.google.com/github/Neum4nn/Engenharia_de_Prompt_e_Aplicacao_AI/blob/main/Programa%C3%A7%C3%A3oAssistidaPorAI_aula07_GuilhermeNeumann.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello word")
# Out:
# wello word

# %% [markdown]
# # Aula 07 _ Miniprojeto
#
# Nome:Guilherme Neumann
#
# Disciplina: Engenharia de Prompt e aplicação em IA
